# %%
from PIL import Image
from random import sample
from os.path import join
from os import listdir
import matplotlib.pyplot as plt

# %%
img = Image.open('C:\makehuman\screenshot.png')

# %%
plt.imshow(img)
plt.show()

# %%
img.size
# Out:
# (1500, 1000)

# %%
img1=img.crop((920,140,1050,280))
plt.imshow(img1)
plt.show()

# %%
img1.save('face11.jpg')
